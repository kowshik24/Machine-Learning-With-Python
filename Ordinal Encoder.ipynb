# %%
import pandas as pd
import numpy as np
import random as rnd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import f1_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC , LinearSVR
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier,SGDRegressor
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OrdinalEncoder,StandardScaler,LabelEncoder,OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report

# %%
df = pd.read_csv(r'F:\Machine Learning\StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
race_order = ['group E' , 'group D' , 'group C' , 'group B' , 'group A']

# %%
encod = OrdinalEncoder(categories=[race_order])

encod.fit(df[['race/ethnicity']])
# Out:
# OrdinalEncoder(categories=[['group E', 'group D', 'group C', 'group B',
#                             'group A']])

# %%
final = pd.DataFrame(encod.transform(df[['race/ethnicity']]))

# %%
df['race/ethnicity'] = final

# %%
df
# Out:
#      gender  race/ethnicity parental level of education         lunch  \
# 0    female             3.0           bachelor's degree      standard
# 1    female             2.0                some college      standard
# 2    female             3.0             master's degree      standard
# 3      male             4.0          associate's degree  free/reduced
# 4      male             2.0                some college      standard
# ..      ...             ...                         ...           ...
# 995  female             0.0             master's degree      standard
# 996    male             2.0                 high school  free/reduced
# 997  female             2.0                 high school  free/reduced
# 998  female             1.0                some college      standard
# 999  female             1.0                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
le = LabelEncoder()

# %%
df['parental level of education'] = le.fit_transform(df['parental level of education'])

# %%
df
# Out:
#      gender  race/ethnicity  parental level of education         lunch  \
# 0    female             3.0                            1      standard
# 1    female             2.0                            4      standard
# 2    female             3.0                            3      standard
# 3      male             4.0                            0  free/reduced
# 4      male             2.0                            4      standard
# ..      ...             ...                          ...           ...
# 995  female             0.0                            3      standard
# 996    male             2.0                            2  free/reduced
# 997  female             2.0                            2  free/reduced
# 998  female             1.0                            4      standard
# 999  female             1.0                            4  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
df['lunch'] = le.fit_transform(df['lunch'])

# %%
df
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0    female             3.0                            1      1
# 1    female             2.0                            4      1
# 2    female             3.0                            3      1
# 3      male             4.0                            0      0
# 4      male             2.0                            4      1
# ..      ...             ...                          ...    ...
# 995  female             0.0                            3      1
# 996    male             2.0                            2      0
# 997  female             2.0                            2      0
# 998  female             1.0                            4      1
# 999  female             1.0                            4      0
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
df['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
df['test preparation course'] = le.fit_transform(df['test preparation course'])

# %%
df
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0    female             3.0                            1      1
# 1    female             2.0                            4      1
# 2    female             3.0                            3      1
# 3      male             4.0                            0      0
# 4      male             2.0                            4      1
# ..      ...             ...                          ...    ...
# 995  female             0.0                            3      1
# 996    male             2.0                            2      0
# 997  female             2.0                            2      0
# 998  female             1.0                            4      1
# 999  female             1.0                            4      0
#
#      test preparation course  math score  reading score  writing score
# 0                          1          72             72             74
# ...

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
df['gender'] = le.fit_transform(df['gender'])

# %%
df
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         0             3.0                            1      1
# 1         0             2.0                            4      1
# 2         0             3.0                            3      1
# 3         1             4.0                            0      0
# 4         1             2.0                            4      1
# ..      ...             ...                          ...    ...
# 995       0             0.0                            3      1
# 996       1             2.0                            2      0
# 997       0             2.0                            2      0
# 998       0             1.0                            4      1
# 999       0             1.0                            4      0
#
#      test preparation course  math score  reading score  writing score
# 0                          1          72             72             74
# ...
